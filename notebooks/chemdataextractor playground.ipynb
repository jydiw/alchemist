# %%
import chemdataextractor as cde
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# ## Types of balancing questions:
#
# - Reaction without product. Problem statement.
#     Sodium metal reacts with chlorine gas in a combination reaction. Write a balanced equation to describe this reaction.
# - Reaction with product. Problem statement.
#     Sodium metal reacts with chlorine gas to form sodium chloride.
#     Sodium metal and chlorine gas react to form sodium chloride.
# - Problem statement: equation.
#     Balance the following equation: Na(s) + Cl2(g) -> NaCl(s)
# - Problem statement, reaction.
#     Write a balanced chemical equation to describe the reaction between sodium metal and chlorine gas.
#     Complete and balance the equations for each of the following reactions.

# %%
reaction_phrases = [
    'methane reacts with oxygen to form carbon dioxide and water vapor.',
    'CH4 reacts with O2 to form CO2 and H2O.',
    'oxygen and methane react to form carbon dioxide and water.',
    'methane and oxygen react in a combustion reaction.',
    'methane combusts in the presence of oxygen.',
    'write a balanced chemical equation to describe the combustion of methane and oxygen.',
    'carbon dioxide is formed when methane combusts in oxygen.'
]

for r in reaction_phrases:
    r1 = cde.doc.Paragraph(r)
    print(r1.pos_tagged_tokens)
    print(r1.cems)
    print('===========')
    print()
# Out:
# [[('methane', 'NN'), ('reacts', 'VBZ'), ('with', 'IN'), ('oxygen', 'NN'), ('to', 'TO'), ('form', 'VB'), ('carbon', 'NN'), ('dioxide', 'NN'), ('and', 'CC'), ('water', 'NN'), ('vapor', 'NN'), ('.', '.')]]
# [Span('methane', 0, 7), Span('oxygen', 20, 26), Span('carbon dioxide', 35, 49)]
# ===========
#
# [[('CH4', 'NN'), ('reacts', 'VBZ'), ('with', 'IN'), ('O2', 'NN'), ('to', 'TO'), ('form', 'VB'), ('CO2', 'NN'), ('and', 'CC'), ('H2O', 'NN'), ('.', '.')]]
# [Span('CH4', 0, 3), Span('O2', 16, 18), Span('CO2', 27, 30), Span('H2O', 35, 38)]
# ===========
#
# [[('oxygen', 'NN'), ('and', 'CC'), ('methane', 'NN'), ('react', 'VBP'), ('to', 'TO'), ('form', 'VB'), ('carbon', 'NN'), ('dioxide', 'NN'), ('and', 'CC'), ('water', 'NN'), ('.', '.')]]
# [Span('oxygen', 0, 6), Span('methane', 11, 18), Span('carbon dioxide', 33, 47)]
# ===========
#
# [[('methane', 'NN'), ('and', 'CC'), ('oxygen', 'NN'), ('react', 'NN'), ('in', 'IN'), ('a', 'DT'), ('combustion', 'NN'), ('reaction', 'NN'), ('.', '.')]]
# [Span('methane', 0, 7), Span('oxygen', 12, 18)]
# ===========
#
# [[('methane', 'NN'), ('combusts', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('presence', 'NN'), ('of', 'IN'), ('oxygen', 'NN'), ('.', '.')]]
# [Span('methane', 0, 7), Span('oxygen', 36, 42)]
# ===========
#
# [[('write', 'VB'), ('a', 'DT'), ('balanced', 'JJ'), ('chemical', 'NN'), ('equation', 'NN'), ('to', 'TO'), ('describe', 'VB'), ('the', 'DT'), ('combustion', 'NN'), ('of', 'IN'), ('methane', 'NN'), ('and', 'CC'), ('oxygen', 'NN'), ('.', '.')]]
# [Span('methane', 65, 72), Span('oxygen', 77, 83)]
# ===========
#
# [[('carbon', 'NN'), ('dioxide', 'NN'), ('is', 'VBZ'), ('formed', 'VBN'), ('when', 'WRB'), ('methane', 'NN'), ('combusts', 'NNS'), ('in', 'IN'), ('oxygen', 'NN'), ('.', '.')]]
# [Span('carbon dioxide', 0, 14), Span('methane', 30, 37), Span('oxygen', 50, 56)]
# ===========

# %%
r2 = cde.doc.Paragraph('''What is the electron configuration of radon?''')
r2.pos_tagged_tokens
# Out:
# [[('What', 'WP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('electron', 'NN'),
#   ('configuration', 'NN'),
#   ('of', 'IN'),
#   ('radon', 'NN'),
#   ('?', '.')]]

# %%
r2.cems
# Out:
# [Span('radon', 38, 43)]

# %%
z = Problem(sample)

# %%
z.question

# %%
print(z.inference)
# Out:
# None

# %%
def remove_stops(doc, i=0, progress=None):
    if progress:
        progress(i)
    doc = word_tokenize(doc)  # Split into words.
    doc = [w.lower() for w in doc if not w in stop_words]  # Remove stopwords.
    doc = [w for w in doc if w.isalpha()]  # Remove numbers and punctuation.
    return doc

# %%
balance_phrases = [
    'balance the following equations',
    'balance the following chemical equation',
    'complete and balance the equation',
    'use coefficients to balance each equation',
    'write a balanced chemical equation',
    'write a balanced molecular equation',
    'what is the balanced chemical equation',
    'when the equation above is balanced with lowest whole-number coefficients, the coefficient for is'
]

balanced = [remove_stops(sent) for sent in balance_phrases]
balanced
# Out:
# [['balance', 'following', 'equations'],
#  ['balance', 'following', 'chemical', 'equation'],
#  ['complete', 'balance', 'equation'],
#  ['use', 'coefficients', 'balance', 'equation'],
#  ['write', 'balanced', 'chemical', 'equation'],
#  ['write', 'balanced', 'molecular', 'equation'],
#  ['balanced', 'chemical', 'equation'],
#  ['equation', 'balanced', 'lowest', 'coefficients', 'coefficient']]

# %%
model = pickle.load(open('../model/model.p', 'rb'))
w2v = pickle.load(open('../model/w2v.p', 'rb'))

word_vectors = model.wv

# %%
probs = pd.read_csv('../data/textbook-problems.csv')

# %%
probs.head()
# Out:
#   filepath  number                                               text  \
# 0  bauer-5       1  Consider the following molecular-level diagram...
# 1  bauer-5       2  Consider the following molecular-level diagram...
# 2  bauer-5       3  Balance the following chemical equations. Clas...
# 3  bauer-5       4  Balance the following equations and classify t...
# 4  bauer-5       5  When heated, nickel(II) carbonate undergoes a ...
#
#                                                  txt  balancing  e_config  \
# 0  ['consider', 'following', 'diagrams', 'chemica...          0         0
# 1  ['consider', 'following', 'diagrams', 'chemica...          0         0
# 2  ['balance', 'following', 'chemical', 'equation...          1         0
# 3  ['balance', 'following', 'equations', 'classif...          1         0
# 4  ['when', 'heated', 'nickel', 'ii', 'carbonate'...          1         0
#
#    distance  distlist
# 0  4.080827       NaN
# 1  4.080827       NaN
# 2  3.988288       NaN
# 3  3.983582       NaN
# 4  4.066166       NaN

# %%
for i in probs.index:
    distlist = [word_vectors.wmdistance(probs.loc[i, 'txt'], ' '.join(j)) for j in balanced]
    probs.loc[i, 'distance'] = np.mean(distlist)
probs.sort_values(by='distance')[:50]
# Out:
#        filepath  number                                               text  \
# 52      bauer-5      53  Add the physical state for each substance in t...
# 12      bauer-5      13  Complete and balance the equations for each of...
# 33      bauer-5      34  Write a balanced equation to describe any acid...
# 229       tro-7      34  Consider the unbalanced chemical equation. Al(...
# 32      bauer-5      33  Write a balanced equation to describe any acid...
# 10      bauer-5      11  Complete and balance the equation for each of ...
# 9       bauer-5      10  Sodium metal reacts with chlorine gas in a com...
# 11      bauer-5      12  Complete and balance the equation for each of ...
# 275       tro-7      80  A beaker of nitric acid is neutralized with ca...
# 29      bauer-5      30  Aqueous ammonium chromate reacts with aqueous ...
# 226       tro-7      31  For each chemical equation (which may or may n...
# 28      bauer-5      29  Aqueous calcium chloride reacts with aqueous p...
# 65      bauer-5      66  Heating causes the copper mineral malachite,  ...
# 24      bauer-5      25  Complete and balance the equation for each of ...
# 200       tro-7       5  What does each abbreviation, often used in che...
# 53      bauer-5      54  Add the physical state for each substance in t...
# 284       tro-7      89  Write a balanced chemical equation for the syn...
# 227       tro-7      32  For each chemical equation (which may or may n...
# 6       bauer-5       7  Complete and balance the equation for each of ...
# 54      bauer-5      55  When aqueous solutions of sodium carbonate and...
# 72      bauer-5      73  Consider the following net ionic equation: H+(...
# 58      bauer-5      59  Consider the following molecular-level diagram...
# 13      bauer-5      14  Complete and balance each of the following sin...
# 55      bauer-5      56  When aqueous solutions of potassium chromate a...
# 63      bauer-5      64  Predict whether reactions should occur between...
# 290       tro-7      95  Predict the products of each reaction and writ...
# 122     bauer-7      46  Write the electron configuration for each of t...
# 8       bauer-5       9  Magnesium metal reacts with oxygen gas in a  c...
# 228       tro-7      33  Consider the unbalanced chemical equation. H2O...
# 202       tro-7       7  Is the chemical equation balanced? Why or why ...
# 201       tro-7       6  To balance a chemical equation, adjust the ___...
# 471  zumdahl-11      89  In each of the following sets of elements, ind...
# 142     bauer-7      66  Write the abbreviated electron configuration f...
# 479   zumdahl-6       6  Nitric acid, HNO3, can be produced by reacting...
# 211       tro-7      16  Describe the differences between a molecular e...
# 23      bauer-5      24  Write a balanced equation to describe any prec...
# 22      bauer-5      23  Write a balanced equation to describe any prec...
# 291       tro-7      96  Predict the products of each reaction and writ...
# 15      bauer-5      16  Iron metal reacts with a solution of copper(II...
# 285       tro-7      90  Write a balanced chemical equation for the syn...
# 4       bauer-5       5  When heated, nickel(II) carbonate undergoes a ...
# 292       tro-7      97  Predict the products of each reaction and writ...
# 293       tro-7      98  Predict the products of each reaction and writ...
# 16      bauer-5      17  Consider the following metals. Determine which...
# 141     bauer-7      65  Write the abbreviated electron configuration f...
# 42      bauer-5      43  Indicate whether each of the following substan...
# 241       tro-7      46  Write a balanced chemical equation for the rea...
# 43      bauer-5      44  Indicate whether each of the following substan...
# 62      bauer-5      63  Predict whether reactions should occur between...
# 74      bauer-5      75  What reaction, if any, occurs if a piece of co...
#
#                                                    txt  balancing  e_config  \
# 52   ['add', 'physical', 'state', 'substance', 'fol...          1         0
# 12   ['complete', 'balance', 'equations', 'followin...          1         0
# 33   ['write', 'balanced', 'equation', 'describe', ...          1         0
# 229  ['consider', 'unbalanced', 'chemical', 'equati...          1         0
# 32   ['write', 'balanced', 'equation', 'describe', ...          1         0
# 10   ['complete', 'balance', 'equation', 'following...          1         0
# 9    ['sodium', 'metal', 'reacts', 'chlorine', 'gas...          1         0
# 11   ['complete', 'balance', 'equation', 'following...          1         0
# 275  ['a', 'beaker', 'nitric', 'acid', 'neutralized...          1         0
# 29   ['aqueous', 'ammonium', 'chromate', 'reacts', ...          1         0
# 226  ['for', 'chemical', 'equation', 'balanced', 'l...          1         0
# 28   ['aqueous', 'calcium', 'chloride', 'reacts', '...          1         0
# 65   ['heating', 'causes', 'copper', 'mineral', 'ma...          1         0
# 24   ['complete', 'balance', 'equation', 'following...          1         0
# 200  ['what', 'abbreviation', 'often', 'used', 'che...          0         0
# 53   ['add', 'physical', 'state', 'substance', 'fol...          1         0
# 284  ['write', 'balanced', 'chemical', 'equation', ...          1         0
# 227  ['for', 'chemical', 'equation', 'balanced', 'l...          1         0
# 6    ['complete', 'balance', 'equation', 'following...          1         0
# 54   ['when', 'aqueous', 'solutions', 'sodium', 'ca...          1         0
# 72   ['consider', 'following', 'net', 'ionic', 'equ...          0         0
# 58   ['consider', 'following', 'diagram', 'reaction...          1         0
# 13   ['complete', 'balance', 'following', 'single',...          1         0
# 55   ['when', 'aqueous', 'solutions', 'potassium', ...          1         0
# 63   ['predict', 'whether', 'reactions', 'occur', '...          1         0
# 290  ['predict', 'products', 'reaction', 'write', '...          1         0
# 122  ['write', 'electron', 'configuration', 'follow...          0         1
# 8    ['magnesium', 'metal', 'reacts', 'oxygen', 'ga...          1         0
# 228  ['consider', 'unbalanced', 'chemical', 'equati...          1         0
# 202  ['is', 'chemical', 'equation', 'balanced', 'wh...          1         0
# 201  ['to', 'balance', 'chemical', 'equation', 'adj...          0         0
# 471  ['in', 'following', 'sets', 'elements', 'indic...          0         0
# 142  ['write', 'abbreviated', 'electron', 'configur...          0         1
# 479  ['nitric', 'acid', 'produced', 'reacting', 'hi...          0         0
# 211  ['describe', 'differences', 'molecular', 'equa...          0         0
# 23   ['write', 'balanced', 'equation', 'describe', ...          1         0
# 22   ['write', 'balanced', 'equation', 'describe', ...          1         0
# 291  ['predict', 'products', 'reaction', 'write', '...          1         0
# 15   ['iron', 'metal', 'reacts', 'solution', 'coppe...          1         0
# 285  ['write', 'balanced', 'chemical', 'equation', ...          1         0
# 4    ['when', 'heated', 'nickel', 'ii', 'carbonate'...          1         0
# 292  ['predict', 'products', 'reaction', 'write', '...          1         0
# 293  ['predict', 'products', 'reaction', 'write', '...          1         0
# 16   ['consider', 'following', 'metals', 'determine...          1         0
# 141  ['write', 'abbreviated', 'electron', 'configur...          0         1
# 42   ['indicate', 'whether', 'following', 'substanc...          0         0
# 241  ['write', 'balanced', 'chemical', 'equation', ...          1         0
# 43   ['indicate', 'whether', 'following', 'substanc...          0         0
# 62   ['predict', 'whether', 'reactions', 'occur', '...          1         0
# 74   ['what', 'reaction', 'occurs', 'piece', 'coppe...          0         0
#
#      distance  distlist  dist-list
# 52   0.664386       NaN        NaN
# 12   0.678309       NaN        NaN
# 33   0.678775       NaN        NaN
# 229  0.679457       NaN        NaN
# 32   0.688059       NaN        NaN
# 10   0.691208       NaN        NaN
# 9    0.692503       NaN        NaN
# 11   0.696141       NaN        NaN
# 275  0.701652       NaN        NaN
# 29   0.705137       NaN        NaN
# 226  0.707159       NaN        NaN
# 28   0.707329       NaN        NaN
# 65   0.709391       NaN        NaN
# 24   0.715300       NaN        NaN
# 200  0.720559       NaN        NaN
# 53   0.723560       NaN        NaN
# 284  0.725447       NaN        NaN
# 227  0.728386       NaN        NaN
# 6    0.732535       NaN        NaN
# 54   0.734980       NaN        NaN
# 72   0.737993       NaN        NaN
# 58   0.740550       NaN        NaN
# 13   0.747762       NaN        NaN
# 55   0.748787       NaN        NaN
# 63   0.749406       NaN        NaN
# 290  0.749783       NaN        NaN
# 122  0.752535       NaN        NaN
# 8    0.754465       NaN        NaN
# 228  0.757152       NaN        NaN
# 202  0.760729       NaN        NaN
# 201  0.763064       NaN        NaN
# 471  0.764343       NaN        NaN
# 142  0.765520       NaN        NaN
# 479  0.768790       NaN        NaN
# 211  0.770459       NaN        NaN
# 23   0.771967       NaN        NaN
# 22   0.773115       NaN        NaN
# 291  0.775617       NaN        NaN
# 15   0.776889       NaN        NaN
# 285  0.783271       NaN        NaN
# 4    0.783635       NaN        NaN
# 292  0.785383       NaN        NaN
# 293  0.786299       NaN        NaN
# 16   0.787481       NaN        NaN
# 141  0.788077       NaN        NaN
# 42   0.789208       NaN        NaN
# 241  0.789358       NaN        NaN
# 43   0.791521       NaN        NaN
# 62   0.796157       NaN        NaN
# 74   0.797126       NaN        NaN
